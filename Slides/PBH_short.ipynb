# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
BH = plt.Circle((0,0), 0.2, color='k')

fig, ax= plt.subplots()
camera = Camera(fig)
ax.add_patch(BH)

ax.set_ylim(ymin=-1.0, ymax=1.0)
ax.set_xlim(xmin=-1.0, xmax=1.0)
# Out:
# (-1.0, 1.0)
